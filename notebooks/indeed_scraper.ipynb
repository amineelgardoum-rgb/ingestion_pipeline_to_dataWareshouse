# %%
import csv
import os
import pandas as pd
from jobspy import scrape_jobs

# ---- Configure your search here ----
city     = "Casablanca"
country  = "Morocco"
data_dir = "../data"
# ------------------------------------

os.makedirs(data_dir, exist_ok=True)

# Multiple search terms to multiply results
search_terms = [
    # ── Data & Analytics ──────────────────────────────
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Analytics Engineer",
    "ETL Developer",
    "Data Warehouse Engineer",
    "Big Data Engineer",
    "Business Intelligence Developer",
    "Power BI Developer",
    "dbt Developer",
    "Data Architect",
    "Data Governance",
    "Data Quality Engineer",
    "Data Ops Engineer",
    "Reporting Analyst",
    "Tableau Developer",
    "Looker Developer",
    "Qlik Developer",
    "Data Modeler",
    "Statistical Analyst",

    # ── Cloud & Platform ──────────────────────────────
    "Azure Data Engineer",
    "AWS Data Engineer",
    "GCP Data Engineer",
    "Cloud Engineer",
    "Cloud Architect",
    "DevOps Engineer",
    "Platform Engineer",
    "Site Reliability Engineer",
    "Kubernetes Engineer",
    "Terraform Engineer",
    "Azure DevOps Engineer",
    "AWS Solutions Architect",
    "Cloud Infrastructure Engineer",
    "FinOps Engineer",

    # ── AI & Machine Learning ─────────────────────────
    "AI Engineer",
    "ML Engineer",
    "Machine Learning Engineer",
    "NLP Engineer",
    "Computer Vision Engineer",
    "MLOps Engineer",
    "Deep Learning Engineer",
    "AI Research Scientist",
    "Generative AI Engineer",
    "LLM Engineer",
    "Prompt Engineer",
    "AI Product Manager",
    "Reinforcement Learning Engineer",

    # ── Software Engineering ──────────────────────────
    "Backend Engineer",
    "Frontend Engineer",
    "Full Stack Developer",
    "Software Engineer",
    "API Developer",
    "Microservices Engineer",
    "Java Developer",
    "Python Developer",
    "Node.js Developer",
    ".NET Developer",
    "React Developer",
    "Angular Developer",
    "Mobile Developer",
    "Flutter Developer",
    "Kotlin Developer",

    # ── Architecture & Leadership ─────────────────────
    "Solution Architect",
    "Enterprise Architect",
    "Technical Lead",
    "Engineering Manager",
    "CTO",
    "VP Engineering",
    "Software Architect",
    "Integration Architect",

    # ── Cybersecurity ─────────────────────────────────
    "Cybersecurity Engineer",
    "Security Analyst",
    "Penetration Tester",
    "SOC Analyst",
    "Cloud Security Engineer",
    "Application Security Engineer",
    "SIEM Engineer",
    "Identity Access Management",

    # ── Infrastructure & Networking ───────────────────
    "Network Engineer",
    "Infrastructure Engineer",
    "Systems Administrator",
    "Linux Administrator",
    "Database Administrator",
    "Storage Engineer",
    "Virtualization Engineer",

    # ── ERP & Business Systems ────────────────────────
    "SAP Consultant",
    "SAP ABAP Developer",
    "Oracle ERP Consultant",
    "Salesforce Developer",
    "Dynamics 365 Developer",
    "ServiceNow Developer",
    "ERP Consultant",

    # ── QA & Testing ──────────────────────────────────
    "QA Engineer",
    "Test Automation Engineer",
    "Performance Engineer",
    "SDET",

    # ── Product & Project ─────────────────────────────
    "Product Manager",
    "Scrum Master",
    "Agile Coach",
    "Project Manager IT",
    "Business Analyst",
    "Functional Analyst",

    # ── Morocco-specific French terms ─────────────────
    "Ingénieur Data",
    "Ingénieur Logiciel",
    "Développeur Full Stack",
    "Ingénieur DevOps",
    "Architecte Cloud",
    "Consultant SAP",
    "Chef de Projet IT",
    "Analyste Fonctionnel",
    "Ingénieur Cybersécurité",
    "Développeur Python",

    # ══════════════════════════════════════════════════
    # ── NEW: Web & PHP (very common in Morocco) ───────
    # ══════════════════════════════════════════════════
    "PHP Developer",
    "PHP Full Stack Developer",
    "Laravel Developer",
    "Symfony Developer",
    "Vue.js Developer",
    "React Native Developer",
    "WordPress Developer",
    "Drupal Developer",
    "Web Developer",
    "Frontend Developer",

    # ── NEW: Mobile (growing fast in Morocco) ─────────
    "iOS Developer",
    "Android Developer",
    "Swift Developer",
    "Xamarin Developer",
    "Ionic Developer",

    # ── NEW: IT Support & Helpdesk ────────────────────
    # (very large hiring category in Morocco's call centers
    #  and shared services centers)
    "IT Support Engineer",
    "IT Helpdesk Technician",
    "Technical Support Engineer",
    "IT Technician",
    "Field Service Engineer",
    "IT Support Analyst",
    "Support Informatique",          # French
    "Technicien Informatique",       # French
    "Technicien Helpdesk",           # French
    "Administrateur Systèmes",       # French

    # ── NEW: Telecom (strong sector in Morocco) ────────
    "Telecom Engineer",
    "Network Administrator",
    "VoIP Engineer",
    "IP Network Engineer",
    "RF Engineer",
    "NOC Engineer",
    "Ingénieur Télécoms",            # French

    # ── NEW: IT Consulting & Offshoring ───────────────
    # (Morocco is a major nearshore hub for Europe)
    "IT Consultant",
    "Technical Consultant",
    "Functional Consultant",
    "AMOA Consultant",               # very common French term
    "MOA Consultant",
    "Consultant Technique",          # French
    "Consultant Fonctionnel",        # French
    "Ingénieur d'Études",            # French - common job title
    "Ingénieur de Développement",    # French

    # ── NEW: Digital Marketing & E-commerce Tech ──────
    "SEO Specialist",
    "Digital Marketing Manager",
    "E-commerce Developer",
    "Growth Hacker",
    "CRM Developer",
    "Marketing Automation Specialist",

    # ── NEW: Embedded & Industrial (automotive/aero) ──
    # (Casablanca & Tanger have large automotive clusters)
    "Embedded Systems Engineer",
    "Firmware Engineer",
    "SCADA Engineer",
    "Automation Engineer",
    "IoT Engineer",
    "C++ Developer",
    "Ingénieur Systèmes Embarqués",  # French
    "Ingénieur Automatisme",         # French

    # ── NEW: GIS & Geospatial ─────────────────────────
    "GIS Developer",
    "Geospatial Engineer",
    "GIS Analyst",

    # ── NEW: Blockchain & Fintech ─────────────────────
    "Blockchain Developer",
    "Smart Contract Developer",
    "Fintech Developer",

    # ── NEW: IT Governance & Risk (GRC) ───────────────
    "IT Auditor",
    "GRC Analyst",
    "CISO",
    "Risk Manager IT",
    "DPO",                           # Data Protection Officer - CNDP in Morocco
    "ISO 27001 Consultant",
    "Responsable Sécurité SI",       # French - RSSI

    # ── NEW: DevSecOps & Modern Infra ─────────────────
    "DevSecOps Engineer",
    "GitOps Engineer",
    "Ansible Engineer",
    "CI/CD Engineer",
    "Jenkins Engineer",
    "OpenShift Engineer",

    # ── NEW: Microsoft Ecosystem ──────────────────────
    # (very large in Morocco's enterprise market)
    "Power Platform Developer",
    "Power Apps Developer",
    "Power Automate Developer",
    "Microsoft 365 Consultant",
    "SharePoint Developer",
    "Azure Administrator",

    # ── NEW: French terms for common roles ────────────
    "Développeur Java",
    "Développeur .NET",
    "Développeur PHP",
    "Développeur React",
    "Développeur Mobile",
    "Développeur Angular",
    "Développeur Node.js",
    "Ingénieur Cloud",
    "Ingénieur Réseaux",
    "Ingénieur Systèmes",
    "Ingénieur QA",
    "Responsable Informatique",
    "Directeur des Systèmes d'Information",   # DSI
    "Architecte Logiciel",
    "Lead Développeur",
    "Scrum Master",
    "Product Owner",
    "Testeur Logiciel",
    "Développeur Salesforce",
    "Développeur ServiceNow",
]

# Multiple locations to multiply results
locations = [
    "Morocco",
    "Casablanca",
    "Rabat",
    "Tanger",
    "Marrakech",
]

all_jobs = []

for term in search_terms:
    for location in locations:
        try:
            print(f"Scraping: '{term}' in '{location}'...")
            jobs = scrape_jobs(
                site_name=["indeed"],
                search_term=term,
                location=location,
                results_wanted=50,
                hours_old=168,
                country_indeed=country,
                # linkedin_fetch_description=True,
            )
            all_jobs.append(jobs)
            print(f"  → {len(jobs)} jobs found")

        except Exception as e:
            print(f"  → Failed: {e}")

# Combine all results
combined = pd.concat(all_jobs, ignore_index=True)

# Deduplicate by job URL
before = len(combined)
combined = combined.drop_duplicates(subset=["job_url"])
after = len(combined)
print(f"\nDeduplication: {before} → {after} unique jobs")

filename = os.path.join(data_dir, f"jobs_{city.lower()}_indeed.tsv")
# Clean all string columns — remove newlines and tabs that break TSV
def clean_text(val):
    if isinstance(val, str):
        val = val.replace('\n', ' ')   # newlines → space
        val = val.replace('\r', ' ')   # carriage returns → space
        val = val.replace('\t', ' ')   # tabs → space (important for TSV!)
        val = ' '.join(val.split())    # collapse multiple spaces
    return val


    # Save as TSV
    filename = os.path.join(data_dir, f"jobs_{city.lower()}_indeed.tsv")
    combined.to_csv(
        filename,
        sep="\t",
        index=False,
        encoding="utf-8",
        lineterminator="\n"
    )
    print(f"Saved to: {os.path.abspath(filename)}")
# Out:
# Scraping: 'Data Engineer' in 'Morocco'...
#   → 27 jobs found
# Scraping: 'Data Engineer' in 'Casablanca'...
#   → 8 jobs found
# Scraping: 'Data Engineer' in 'Rabat'...
#   → 7 jobs found
# Scraping: 'Data Engineer' in 'Tanger'...
#   → 5 jobs found
# Scraping: 'Data Engineer' in 'Marrakech'...
#   → 3 jobs found
# Scraping: 'Data Analyst' in 'Morocco'...
#   → 17 jobs found
# Scraping: 'Data Analyst' in 'Casablanca'...
#   → 11 jobs found
# Scraping: 'Data Analyst' in 'Rabat'...
#   → 2 jobs found
# Scraping: 'Data Analyst' in 'Tanger'...
#   → 3 jobs found
# Scraping: 'Data Analyst' in 'Marrakech'...
#   → 0 jobs found
# Scraping: 'Data Scientist' in 'Morocco'...
#   → 10 jobs found
# Scraping: 'Data Scientist' in 'Casablanca'...
#   → 10 jobs found
# Scraping: 'Data Scientist' in 'Rabat'...
#   → 0 jobs found
# Scraping: 'Data Scientist' in 'Tanger'...
#   → 0 jobs found
# Scraping: 'Data Scientist' in 'Marrakech'...
#   → 0 jobs found
# ...
