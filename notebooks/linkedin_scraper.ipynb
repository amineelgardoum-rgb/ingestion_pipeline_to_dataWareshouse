# %%
import csv
import os
import pandas as pd
from jobspy import scrape_jobs

# ---- Configure your search here ----
city     = "Casablanca"
country  = "Morocco"
data_dir = "../data"
# ------------------------------------

os.makedirs(data_dir, exist_ok=True)

# Multiple search terms to multiply results
search_terms = [
    # ── Data & Analytics ──────────────────────────────
    "Data Engineer",
    "Data Analyst",
    "Data Scientist",
    "Analytics Engineer",
    "ETL Developer",
    "Data Warehouse Engineer",
    "Big Data Engineer",
    "Business Intelligence Developer",
    "Power BI Developer",
    "dbt Developer",
    "Data Architect",
    "Data Governance",
    "Data Quality Engineer",
    "Data Ops Engineer",
    "Reporting Analyst",
    "Tableau Developer",
    "Looker Developer",
    "Qlik Developer",
    "Data Modeler",
    "Statistical Analyst",

    # ── Cloud & Platform ──────────────────────────────
    "Azure Data Engineer",
    "AWS Data Engineer",
    "GCP Data Engineer",
    "Cloud Engineer",
    "Cloud Architect",
    "DevOps Engineer",
    "Platform Engineer",
    "Site Reliability Engineer",
    "Kubernetes Engineer",
    "Terraform Engineer",
    "Azure DevOps Engineer",
    "AWS Solutions Architect",
    "Cloud Infrastructure Engineer",
    "FinOps Engineer",

    # ── AI & Machine Learning ─────────────────────────
    "AI Engineer",
    "ML Engineer",
    "Machine Learning Engineer",
    "NLP Engineer",
    "Computer Vision Engineer",
    "MLOps Engineer",
    "Deep Learning Engineer",
    "AI Research Scientist",
    "Generative AI Engineer",
    "LLM Engineer",
    "Prompt Engineer",
    "AI Product Manager",
    "Reinforcement Learning Engineer",

    # ── Software Engineering ──────────────────────────
    "Backend Engineer",
    "Frontend Engineer",
    "Full Stack Developer",
    "Software Engineer",
    "API Developer",
    "Microservices Engineer",
    "Java Developer",
    "Python Developer",
    "Node.js Developer",
    ".NET Developer",
    "React Developer",
    "Angular Developer",
    "Mobile Developer",
    "Flutter Developer",
    "Kotlin Developer",

    # ── Architecture & Leadership ─────────────────────
    "Solution Architect",
    "Enterprise Architect",
    "Technical Lead",
    "Engineering Manager",
    "CTO",
    "VP Engineering",
    "Software Architect",
    "Integration Architect",

    # ── Cybersecurity ─────────────────────────────────
    "Cybersecurity Engineer",
    "Security Analyst",
    "Penetration Tester",
    "SOC Analyst",
    "Cloud Security Engineer",
    "Application Security Engineer",
    "SIEM Engineer",
    "Identity Access Management",

    # ── Infrastructure & Networking ───────────────────
    "Network Engineer",
    "Infrastructure Engineer",
    "Systems Administrator",
    "Linux Administrator",
    "Database Administrator",
    "Storage Engineer",
    "Virtualization Engineer",

    # ── ERP & Business Systems ────────────────────────
    "SAP Consultant",
    "SAP ABAP Developer",
    "Oracle ERP Consultant",
    "Salesforce Developer",
    "Dynamics 365 Developer",
    "ServiceNow Developer",
    "ERP Consultant",

    # ── QA & Testing ──────────────────────────────────
    "QA Engineer",
    "Test Automation Engineer",
    "Performance Engineer",
    "SDET",

    # ── Product & Project ─────────────────────────────
    "Product Manager",
    "Scrum Master",
    "Agile Coach",
    "Project Manager IT",
    "Business Analyst",
    "Functional Analyst",

    # ── Morocco-specific French terms ─────────────────
    "Ingénieur Data",
    "Ingénieur Logiciel",
    "Développeur Full Stack",
    "Ingénieur DevOps",
    "Architecte Cloud",
    "Consultant SAP",
    "Chef de Projet IT",
    "Analyste Fonctionnel",
    "Ingénieur Cybersécurité",
    "Développeur Python",

    # ══════════════════════════════════════════════════
    # ── NEW: Web & PHP (very common in Morocco) ───────
    # ══════════════════════════════════════════════════
    "PHP Developer",
    "PHP Full Stack Developer",
    "Laravel Developer",
    "Symfony Developer",
    "Vue.js Developer",
    "React Native Developer",
    "WordPress Developer",
    "Drupal Developer",
    "Web Developer",
    "Frontend Developer",

    # ── NEW: Mobile (growing fast in Morocco) ─────────
    "iOS Developer",
    "Android Developer",
    "Swift Developer",
    "Xamarin Developer",
    "Ionic Developer",

    # ── NEW: IT Support & Helpdesk ────────────────────
    # (very large hiring category in Morocco's call centers
    #  and shared services centers)
    "IT Support Engineer",
    "IT Helpdesk Technician",
    "Technical Support Engineer",
    "IT Technician",
    "Field Service Engineer",
    "IT Support Analyst",
    "Support Informatique",          # French
    "Technicien Informatique",       # French
    "Technicien Helpdesk",           # French
    "Administrateur Systèmes",       # French

    # ── NEW: Telecom (strong sector in Morocco) ────────
    "Telecom Engineer",
    "Network Administrator",
    "VoIP Engineer",
    "IP Network Engineer",
    "RF Engineer",
    "NOC Engineer",
    "Ingénieur Télécoms",            # French

    # ── NEW: IT Consulting & Offshoring ───────────────
    # (Morocco is a major nearshore hub for Europe)
    "IT Consultant",
    "Technical Consultant",
    "Functional Consultant",
    "AMOA Consultant",               # very common French term
    "MOA Consultant",
    "Consultant Technique",          # French
    "Consultant Fonctionnel",        # French
    "Ingénieur d'Études",            # French - common job title
    "Ingénieur de Développement",    # French

    # ── NEW: Digital Marketing & E-commerce Tech ──────
    "SEO Specialist",
    "Digital Marketing Manager",
    "E-commerce Developer",
    "Growth Hacker",
    "CRM Developer",
    "Marketing Automation Specialist",

    # ── NEW: Embedded & Industrial (automotive/aero) ──
    # (Casablanca & Tanger have large automotive clusters)
    "Embedded Systems Engineer",
    "Firmware Engineer",
    "SCADA Engineer",
    "Automation Engineer",
    "IoT Engineer",
    "C++ Developer",
    "Ingénieur Systèmes Embarqués",  # French
    "Ingénieur Automatisme",         # French

    # ── NEW: GIS & Geospatial ─────────────────────────
    "GIS Developer",
    "Geospatial Engineer",
    "GIS Analyst",

    # ── NEW: Blockchain & Fintech ─────────────────────
    "Blockchain Developer",
    "Smart Contract Developer",
    "Fintech Developer",

    # ── NEW: IT Governance & Risk (GRC) ───────────────
    "IT Auditor",
    "GRC Analyst",
    "CISO",
    "Risk Manager IT",
    "DPO",                           # Data Protection Officer - CNDP in Morocco
    "ISO 27001 Consultant",
    "Responsable Sécurité SI",       # French - RSSI

    # ── NEW: DevSecOps & Modern Infra ─────────────────
    "DevSecOps Engineer",
    "GitOps Engineer",
    "Ansible Engineer",
    "CI/CD Engineer",
    "Jenkins Engineer",
    "OpenShift Engineer",

    # ── NEW: Microsoft Ecosystem ──────────────────────
    # (very large in Morocco's enterprise market)
    "Power Platform Developer",
    "Power Apps Developer",
    "Power Automate Developer",
    "Microsoft 365 Consultant",
    "SharePoint Developer",
    "Azure Administrator",

    # ── NEW: French terms for common roles ────────────
    "Développeur Java",
    "Développeur .NET",
    "Développeur PHP",
    "Développeur React",
    "Développeur Mobile",
    "Développeur Angular",
    "Développeur Node.js",
    "Ingénieur Cloud",
    "Ingénieur Réseaux",
    "Ingénieur Systèmes",
    "Ingénieur QA",
    "Responsable Informatique",
    "Directeur des Systèmes d'Information",   # DSI
    "Architecte Logiciel",
    "Lead Développeur",
    "Scrum Master",
    "Product Owner",
    "Testeur Logiciel",
    "Développeur Salesforce",
    "Développeur ServiceNow",
]

# Multiple locations to multiply results
locations = [
    "Morocco",
    "Casablanca",
    "Rabat",
    "Marrakech",
]

all_jobs = []

for term in search_terms:
    for location in locations:
        try:
            print(f"Scraping: '{term}' in '{location}'...")
            jobs = scrape_jobs(
                site_name=["linkedin"],
                search_term=term,
                location=location,
                results_wanted=50,
                hours_old=168,
                linkedin_fetch_description=True,
            )
            all_jobs.append(jobs)
            print(f"  → {len(jobs)} jobs found")

        except Exception as e:
            print(f"  → Failed: {e}")

# Combine all results
combined = pd.concat(all_jobs, ignore_index=True)

# Deduplicate by job URL
before = len(combined)
combined = combined.drop_duplicates(subset=["job_url"])
after = len(combined)
print(f"\nDeduplication: {before} → {after} unique jobs")

filename = os.path.join(data_dir, f"jobs_{city.lower()}_linkedin.tsv")
combined.to_csv(filename,sep="\t",index=False,encoding='UTF-8')
print(f"Saved to: {os.path.abspath(filename)}")
# Out:
# Scraping: 'Data Engineer' in 'Morocco'...
#   → 30 jobs found
# Scraping: 'Data Engineer' in 'Casablanca'...
#   → 26 jobs found
# Scraping: 'Data Engineer' in 'Rabat'...
#   → 15 jobs found
# Scraping: 'Data Engineer' in 'Marrakech'...
#   → 7 jobs found
# Scraping: 'Data Analyst' in 'Morocco'...
#   → 50 jobs found
# Scraping: 'Data Analyst' in 'Casablanca'...
#   → 40 jobs found
# Scraping: 'Data Analyst' in 'Rabat'...
#   → 30 jobs found
# Scraping: 'Data Analyst' in 'Marrakech'...
#   → 9 jobs found
# Scraping: 'Data Scientist' in 'Morocco'...
#   → 50 jobs found
# Scraping: 'Data Scientist' in 'Casablanca'...
#   → 38 jobs found
# Scraping: 'Data Scientist' in 'Rabat'...
#   → 25 jobs found
# Scraping: 'Data Scientist' in 'Marrakech'...
#   → 17 jobs found
# Scraping: 'Analytics Engineer' in 'Morocco'...
#   → 22 jobs found
# Scraping: 'Analytics Engineer' in 'Casablanca'...
#   → 18 jobs found
# Scraping: 'Analytics Engineer' in 'Rabat'...
#   → 8 jobs found
# Scraping: 'Analytics Engineer' in 'Marrakech'...
#   → 6 jobs found
# Scraping: 'ETL Developer' in 'Morocco'...
#   → 21 jobs found
# Scraping: 'ETL Developer' in 'Casablanca'...
#   → 20 jobs found
# Scraping: 'ETL Developer' in 'Rabat'...
#   → 10 jobs found
# Scraping: 'ETL Developer' in 'Marrakech'...
#   → 2 jobs found
# Scraping: 'Data Warehouse Engineer' in 'Morocco'...
#   → 20 jobs found
# Scraping: 'Data Warehouse Engineer' in 'Casablanca'...
#   → 10 jobs found
# Scraping: 'Data Warehouse Engineer' in 'Rabat'...
#   → 8 jobs found
# Scraping: 'Data Warehouse Engineer' in 'Marrakech'...
#   → 2 jobs found
# Scraping: 'Big Data Engineer' in 'Morocco'...
#   → 19 jobs found
# Scraping: 'Big Data Engineer' in 'Casablanca'...
#   → 9 jobs found
# Scraping: 'Big Data Engineer' in 'Rabat'...
#   → 9 jobs found
# Scraping: 'Big Data Engineer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Business Intelligence Developer' in 'Morocco'...
#   → 13 jobs found
# Scraping: 'Business Intelligence Developer' in 'Casablanca'...
#   → 9 jobs found
# Scraping: 'Business Intelligence Developer' in 'Rabat'...
#   → 4 jobs found
# Scraping: 'Business Intelligence Developer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Power BI Developer' in 'Morocco'...
#   → 3 jobs found
# Scraping: 'Power BI Developer' in 'Casablanca'...
#   → 0 jobs found
# Scraping: 'Power BI Developer' in 'Rabat'...
#   → 3 jobs found
# Scraping: 'Power BI Developer' in 'Marrakech'...
#   → 0 jobs found
# Scraping: 'dbt Developer' in 'Morocco'...
#   → 0 jobs found
# Scraping: 'dbt Developer' in 'Casablanca'...
#   → 0 jobs found
# Scraping: 'dbt Developer' in 'Rabat'...
#   → 0 jobs found
# Scraping: 'dbt Developer' in 'Marrakech'...
#   → 0 jobs found
# Scraping: 'Data Architect' in 'Morocco'...
#   → 20 jobs found
# Scraping: 'Data Architect' in 'Casablanca'...
#   → 20 jobs found
# Scraping: 'Data Architect' in 'Rabat'...
#   → 8 jobs found
# Scraping: 'Data Architect' in 'Marrakech'...
#   → 2 jobs found
# Scraping: 'Data Governance' in 'Morocco'...
#   → 17 jobs found
# Scraping: 'Data Governance' in 'Casablanca'...
#   → 10 jobs found
# Scraping: 'Data Governance' in 'Rabat'...
#   → 5 jobs found
# Scraping: 'Data Governance' in 'Marrakech'...
#   → 2 jobs found
# Scraping: 'Data Quality Engineer' in 'Morocco'...
#   → 10 jobs found
# Scraping: 'Data Quality Engineer' in 'Casablanca'...
#   → 1 jobs found
# Scraping: 'Data Quality Engineer' in 'Rabat'...
#   → 5 jobs found
# Scraping: 'Data Quality Engineer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Data Ops Engineer' in 'Morocco'...
#   → 8 jobs found
# Scraping: 'Data Ops Engineer' in 'Casablanca'...
#   → 2 jobs found
# Scraping: 'Data Ops Engineer' in 'Rabat'...
#   → 3 jobs found
# Scraping: 'Data Ops Engineer' in 'Marrakech'...
#   → 0 jobs found
# Scraping: 'Reporting Analyst' in 'Morocco'...
#   → 18 jobs found
# Scraping: 'Reporting Analyst' in 'Casablanca'...
#   → 13 jobs found
# Scraping: 'Reporting Analyst' in 'Rabat'...
#   → 5 jobs found
# Scraping: 'Reporting Analyst' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Tableau Developer' in 'Morocco'...
#   → 3 jobs found
# Scraping: 'Tableau Developer' in 'Casablanca'...
#   → 0 jobs found
# Scraping: 'Tableau Developer' in 'Rabat'...
#   → 3 jobs found
# Scraping: 'Tableau Developer' in 'Marrakech'...
#   → 0 jobs found
# Scraping: 'Looker Developer' in 'Morocco'...
#   → 3 jobs found
# Scraping: 'Looker Developer' in 'Casablanca'...
#   → 0 jobs found
# Scraping: 'Looker Developer' in 'Rabat'...
#   → 2 jobs found
# Scraping: 'Looker Developer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Qlik Developer' in 'Morocco'...
#   → 3 jobs found
# Scraping: 'Qlik Developer' in 'Casablanca'...
#   → 0 jobs found
# Scraping: 'Qlik Developer' in 'Rabat'...
#   → 2 jobs found
# Scraping: 'Qlik Developer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Data Modeler' in 'Morocco'...
#   → 50 jobs found
# Scraping: 'Data Modeler' in 'Casablanca'...
#   → 39 jobs found
# Scraping: 'Data Modeler' in 'Rabat'...
#   → 26 jobs found
# Scraping: 'Data Modeler' in 'Marrakech'...
#   → 9 jobs found
# Scraping: 'Statistical Analyst' in 'Morocco'...
#   → 13 jobs found
# Scraping: 'Statistical Analyst' in 'Casablanca'...
#   → 12 jobs found
# Scraping: 'Statistical Analyst' in 'Rabat'...
#   → 1 jobs found
# Scraping: 'Statistical Analyst' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Azure Data Engineer' in 'Morocco'...
#   → 14 jobs found
# Scraping: 'Azure Data Engineer' in 'Casablanca'...
#   → 8 jobs found
# Scraping: 'Azure Data Engineer' in 'Rabat'...
#   → 6 jobs found
# Scraping: 'Azure Data Engineer' in 'Marrakech'...
#   → 0 jobs found
# Scraping: 'AWS Data Engineer' in 'Morocco'...
#   → 20 jobs found
# Scraping: 'AWS Data Engineer' in 'Casablanca'...
#   → 15 jobs found
# Scraping: 'AWS Data Engineer' in 'Rabat'...
#   → 4 jobs found
# Scraping: 'AWS Data Engineer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'GCP Data Engineer' in 'Morocco'...
#   → 8 jobs found
# Scraping: 'GCP Data Engineer' in 'Casablanca'...
#   → 3 jobs found
# Scraping: 'GCP Data Engineer' in 'Rabat'...
#   → 3 jobs found
# Scraping: 'GCP Data Engineer' in 'Marrakech'...
#   → 2 jobs found
# Scraping: 'Cloud Engineer' in 'Morocco'...
#   → 26 jobs found
# Scraping: 'Cloud Engineer' in 'Casablanca'...
#   → 20 jobs found
# Scraping: 'Cloud Engineer' in 'Rabat'...
#   → 7 jobs found
# Scraping: 'Cloud Engineer' in 'Marrakech'...
#   → 2 jobs found
# Scraping: 'Cloud Architect' in 'Morocco'...
#   → 9 jobs found
# Scraping: 'Cloud Architect' in 'Casablanca'...
#   → 3 jobs found
# Scraping: 'Cloud Architect' in 'Rabat'...
#   → 3 jobs found
# Scraping: 'Cloud Architect' in 'Marrakech'...
#   → 3 jobs found
# Scraping: 'DevOps Engineer' in 'Morocco'...
#   → 17 jobs found
# Scraping: 'DevOps Engineer' in 'Casablanca'...
#   → 11 jobs found
# Scraping: 'DevOps Engineer' in 'Rabat'...
#   → 4 jobs found
# Scraping: 'DevOps Engineer' in 'Marrakech'...
#   → 1 jobs found
# Scraping: 'Platform Engineer' in 'Morocco'...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\DataWarehouseProject\.venv\Lib\site-packages\jobspy\__init__.py:124, in scrape_jobs(site_name, search_term, google_search_term, location, distance, is_remote, job_type, easy_apply, results_wanted, country_indeed, proxies, ca_cert, description_format, linkedin_fetch_description, linkedin_company_ids, offset, hours_old, enforce_annual_salary, verbose, user_agent, **kwargs)
#     120 future_to_site = {
#     121     executor.submit(worker, site): site for site in scraper_input.site_type
#     122 }
# --> 124 for future in as_completed(future_to_site):
#     125     site_value, scraped_data = future.result()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:237, in as_completed(fs, timeout)
#     233         raise TimeoutError(
#     234                 '%d (of %d) futures unfinished' % (
#     235                 len(pending), total_futures))
# --> 237 waiter.event.wait(wait_timeout)
#     239 with waiter.lock:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\threading.py:669, in Event.wait(self, timeout)
#     668 if not signaled:
# --> 669     signaled = self._cond.wait(timeout)
#     670 return signaled
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\threading.py:369, in Condition.wait(self, timeout)
#     368 if timeout is None:
# --> 369     waiter.acquire()
#     370     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 309
#     305             )
#     306             all_jobs.append(jobs)
#     307             print(f"  → {len(jobs)} jobs found")
#     308
# --> 309         except Exception as e:
#     310             print(f"  → Failed: {e}")
#     311
#     312 # Combine all results
#
# File ~\DataWarehouseProject\.venv\Lib\site-packages\jobspy\__init__.py:119, in scrape_jobs(site_name, search_term, google_search_term, location, distance, is_remote, job_type, easy_apply, results_wanted, country_indeed, proxies, ca_cert, description_format, linkedin_fetch_description, linkedin_company_ids, offset, hours_old, enforce_annual_salary, verbose, user_agent, **kwargs)
#     116     site_val, scraped_info = scrape_site(site)
#     117     return site_val, scraped_info
# --> 119 with ThreadPoolExecutor() as executor:
#     120     future_to_site = {
#     121         executor.submit(worker, site): site for site in scraper_input.site_type
#     122     }
#     124     for future in as_completed(future_to_site):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:667, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     666 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 667     self.shutdown(wait=True)
#     668     return False
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\thread.py:273, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     271 if wait:
#     272     for t in self._threads:
# --> 273         t.join()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\threading.py:1132, in Thread.join(self, timeout)
#    1129 if timeout is not None:
#    1130     timeout = max(timeout, 0)
# -> 1132 self._os_thread_handle.join(timeout)
#
# KeyboardInterrupt:
